# %% [markdown]
# # Lab 11 — Classifier Comparison
# This notebook is the interactive companion of `main.py`.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path(__file__).resolve().parents[1] if '__file__' in globals() else Path('.').resolve()
data_path = repo_root / 'data' / 'dataset.csv'
df = pd.read_csv(data_path)
df.head()
